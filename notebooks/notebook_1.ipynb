# %%
import pandas as pd
import sys
sys.path.insert(1,"../scripts/")
from prediction_scripts import predict_batch, predict_single
# Out:
# WARNING (theano.link.c.cmodule): install mkl with `conda install mkl-service`: No module named 'mkl'
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
smile = "BrC1=C(OC2=CC=CC=C2)C=CC3=CC=CC=C31"
predict_single(smile, 2.5)

# %%
smiles = ["BrC1=C(OC2=CC=CC=C2)C=CC3=CC=CC=C31","BrC1=C(OC2=CC=CC=C2)C=CC3=CC=CC=C31",]
conc = [2.5,10]

predict_batch(smiles, conc)
# Out:
#    G′ Predicted Value  G′ Lower CI  G′ Upper CI  G′ CI Range
# 0            3.911774     3.365883     4.301926     0.936043  \
# 1            4.226090     3.561319     4.838908     1.277589
#
#    G″ Predicted Value  G″ Lower CI  G″ Upper CI  G″ CI Range  Conc In Domain?
# 0            3.076177     2.448355     3.668352     1.219997   2.5        Out
# 1            3.500748     2.598026     4.242761     1.644735  10.0        Out
